# %%
import pandas as pd

# %%
df=pd.read_csv("D://DSML PRACTICAL//Datasets//House Data.csv")

# %%
df
# Out:
#        serial     district         price  \
# 0           0       adalar   3,100,000TL
# 1           1       adalar   1,600,000TL
# 2           2       adalar  18,500,000TL
# 3           3       adalar   9,500,000TL
# 4           4       adalar  25,000,000TL
# ...       ...          ...           ...
# 25150   25150  zeytinburnu   1,850,000TL
# 25151   25151  zeytinburnu   1,100,000TL
# 25152   25152  zeytinburnu   9,000,000TL
# 25153   25153  zeytinburnu  13,000,000TL
# 25154   25154  zeytinburnu   1,000,000TL
#
#                                                  address    AdUpdateDate  \
# 0      ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...   24 Şubat 2022
# 1      ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...    02 Mart 2022
# 2      ['Anasayfa', 'Satılık Müstakil Ev', 'İstanbul ...   11 Şubat 2022
# 3      ['Anasayfa', 'Satılık Bina', 'İstanbul Satılık...   11 Şubat 2022
# 4      ['Anasayfa', 'Satılık Köşk', 'İstanbul Satılık...    19 Ocak 2022
# ...

# %%
df.isnull().any()
# Out:
# serial                      False
# district                    False
# price                       False
# address                     False
# AdUpdateDate                False
# Category                    False
# GrossSquareMeters           False
# BuildingAge                 False
# NumberFloorsofBuilding      False
# UsingStatus                 False
# EligibilityForInvestment     True
# BuildStatus                  True
# TitleStatus                  True
# ItemStatus                   True
# NumberOfBathrooms           False
# NumberOfWCs                  True
# AdCreationDate              False
# Type                        False
# NetSquareMeters             False
# NumberOfRooms               False
# FloorLocation               False
# HeatingType                 False
# CreditEligibility           False
# InsideTheSite               False
# StructureType                True
# MortgageStatus               True
# Swap                         True
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = "D://DSML PRACTICAL//Datasets//Covid Vaccine Statewise.csv"
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (7845, 24)

# %%
df.tail()
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# 7840                      NaN                       NaN
# 7841                      NaN                       NaN
# 7842                      NaN                       NaN
# 7843                      NaN                       NaN
# 7844                      NaN                       NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 7840                        NaN                          NaN
# ...

# %%
df['Second Dose Administered'].isnull().sum()
# Out:
# 224

# %%
numeric_df= df.select_dtypes(include=['number'])
numeric_df
# Out:
#       Total Doses Administered  Sessions   Sites   First Dose Administered  \
# 0                      48276.0    3455.0   2957.0                  48276.0
# 1                      58604.0    8532.0   4954.0                  58604.0
# 2                      99449.0   13611.0   6583.0                  99449.0
# 3                     195525.0   17855.0   7951.0                 195525.0
# 4                     251280.0   25472.0  10504.0                 251280.0
# ...                        ...       ...      ...                      ...
# 7840                       NaN       NaN      NaN                      NaN
# 7841                       NaN       NaN      NaN                      NaN
# 7842                       NaN       NaN      NaN                      NaN
# 7843                       NaN       NaN      NaN                      NaN
# 7844                       NaN       NaN      NaN                      NaN
#
#       Second Dose Administered  Male (Doses Administered)  \
# ...

# %%
numeric_df.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
abc=df.groupby(['State'])

# %%
abc.head()
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7633  16/01/2021  West Bengal                    1917.0     114.0    107.0
# 7634  17/01/2021  West Bengal                    2085.0     366.0    191.0
# 7635  18/01/2021  West Bengal                    5060.0     730.0    241.0
# 7636  19/01/2021  West Bengal                   12364.0     916.0    252.0
# 7637  20/01/2021  West Bengal                   14624.0    1405.0    360.0
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
unique_values=df['State'].unique()
unique_values
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
temp_df=df[df['State']!='India']

# %%
temp_df
# Out:
#       Updated On                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
# ...          ...                          ...                       ...
# 7840  11/08/2021                  West Bengal                       NaN
# 7841  12/08/2021                  West Bengal                       NaN
# 7842  13/08/2021                  West Bengal                       NaN
# 7843  14/08/2021                  West Bengal                       NaN
# 7844  15/08/2021                  West Bengal                       NaN
#
#       Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
ng=temp_df.groupby(['State'])['First Dose Administered'].sum()
ng
# Out:
# State
# Andaman and Nicobar Islands                 1.642585e+07
# Andhra Pradesh                              1.232861e+09
# Arunachal Pradesh                           4.900498e+07
# Assam                                       5.856002e+08
# Bihar                                       1.470503e+09
# Chandigarh                                  4.470310e+07
# Chhattisgarh                                7.960029e+08
# Dadra and Nagar Haveli and Daman and Diu    3.359506e+07
# Delhi                                       6.243395e+08
# Goa                                         7.599137e+07
# Gujarat                                     2.131646e+09
# Haryana                                     7.557984e+08
# Himachal Pradesh                            3.162940e+08
# Jammu and Kashmir                           4.101018e+08
# Jharkhand                                   6.036737e+08
# Karnataka                                   1.873330e+09
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
tf=pd.read_csv("D://DSML PRACTICAL//Datasets//Titanic.csv")
# Plot a histogram for the 'Fare' column
plt.figure(figsize=(10, 6))
sns.histplot(tf['Fare'], kde=True, bins=30, color='blue')
plt.title("Distribution of Ticket Prices (Fare)")
plt.xlabel("Fare")
plt.ylabel("Frequency")
plt.show()
